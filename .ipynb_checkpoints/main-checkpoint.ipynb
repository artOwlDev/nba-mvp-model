# %%
years = list(range(1994, 2025))

# %% [markdown]
# ### **Fetch MVP data**

# %%
mvps_base_url = "https://www.basketball-reference.com/awards/awards_{}.html"

# %%
# Get MVP leaderboard from every year in years.

# %%
import time
import requests

# %%
for year in years:
    url = mvps_base_url.format(year)
    data = requests.get(url) # Response

    # Record html. (So you don't send requests every single time)
    with open("mvps/{}.html".format(year), "w+") as f:
        f.write(data.text)

    time.sleep(5)

# %%
from bs4 import BeautifulSoup
import pandas as pd
from io import StringIO

# %%
dataframes = []

# Fetch mvp data from last 30 years.
for year in years:
    with open("mvps/{}.html".format(year), encoding='latin1') as f:
        page = f.read() # Store as string

    soup = BeautifulSoup(page, "html.parser")
    soup.find('tr', class_="over_header").decompose()
    mvp_table = soup.find(id="mvp")
    mvp_table_parsed = pd.read_html(StringIO(str(mvp_table)))[0]
    mvp_table_parsed["Year"] = year
    
    dataframes.append(mvp_table_parsed)

# %%
mvps = pd.concat(dataframes)

# %%
mvps.to_csv("csv/mvps.csv")

# %% [markdown]
# ### **Fetch Player data**

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# Path to the Brave browser executable on macOS
brave_path = "/Applications/Google Chrome.app/Contents/MacOS/Google Chrome"

# Set up ChromeOptions to use Brave
options = Options()
options.binary_location = brave_path

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# %%
import time

url = "https://www.basketball-reference.com/leagues/NBA_{}_per_game.html"

for year in years:
    driver.get(url.format(year))
    driver.execute_script("window.scrollTo(1,10000)")
    time.sleep(5)
    html = driver.page_source

    with open("players/{}.html".format(year), "w+") as f:
        f.write(html)

# %%
dataframes = []

for year in years:
    with open("players/{}.html".format(year)) as f:
        page = f.read()

    soup = BeautifulSoup(page, "html.parser")
    soup.find('tr', class_="thead").decompose()
    players_table = soup.find(id="per_game_stats")
    players_table_parsed = pd.read_html(StringIO(str(players_table)))[0]
    players_table_parsed["Year"] = year

    dataframes.append(players_table_parsed)

# %%
players_stats = pd.concat(dataframes)

# %%
players_stats.to_csv("csv/player_stats.csv")

# %% [markdown]
# ### **Fetch Team Data**

# %%
team_url = "https://www.basketball-reference.com/leagues/NBA_{}_standings.html"

# %%
import time

# %%
for year in years:
    url = team_url.format(year)
    data = requests.get(url)
    time.sleep(5)

    with open("teams/{}.html".format(year), "w+" ) as f:
        f.write(data.text)

# %%
df = []

for year in years:
    with open("teams/{}.html".format(year)) as f:
        page = f.read()
        
    soup = BeautifulSoup(page, "html.parser")
    soup.find('tr', class_='thead').decompose()
    team_table = soup.find(id="divs_standings_E")
    team = pd.read_html(StringIO(str(team_table)))[0]
    team["Year"] = year
    team["Team"] = team["Eastern Conference"]
    del team["Eastern Conference"]
    
    df.append(team)
    
    soup = BeautifulSoup(page, "html.parser")
    soup.find('tr', class_="thead").decompose()
    team_table = soup.find(id="divs_standings_W")
    team = pd.read_html(StringIO(str(team_table)))[0]
    team["Year"] = year
    team["Team"] = team["Western Conference"]
    del team["Western Conference"]
    
    df.append(team)

# %%
teams = pd.concat(df)

# %%
teams.to_csv("csv/teams.csv")

# %% [markdown]
# ### **Data Cleaning**

# %%
mvps = pd.read_csv("csv/mvps.csv", encoding="latin1")

# %%
mvps.tail(30)
# Out:
#      Unnamed: 0 Rank                     Player  Age   Tm  First  Pts Won  \
# 427           4    5  Luka DonÃÂÃÂiÃÂÃÂ   22  DAL      0      146
# 428           5    6               Jayson Tatum   23  BOS      0       43
# 429           6    7                  Ja Morant   22  MEM      0       10
# 430           7    8              Stephen Curry   33  GSW      0        4
# 431           8    9                 Chris Paul   36  PHO      0        2
# 432           9  10T              DeMar DeRozan   32  CHI      0        1
# 433          10  10T               Kevin Durant   33  BRK      0        1
# 434          11  10T               LeBron James   37  LAL      0        1
# 435           0    1                Joel Embiid   28  PHI     73      915
# 436           1    2        Nikola JokiÃÂÃÂ   27  DEN     15      674
# 437           2    3      Giannis Antetokounmpo   28  MIL     12      606
# 438           3    4               Jayson Tatum   24  BOS      0      280
# 439           4    5    Shai Gilgeous-Alexander   24  OKC      0       46
# 440           5    6           Donovan Mitchell   26  CLE      0       30
# 441           6    7           Domantas Sabonis   26  SAC      0       27
# 442           7    8  Luka DonÃÂÃÂiÃÂÃÂ   23  DAL      0       10
# 443           8    9              Stephen Curry   34  GSW      0        5
# 444           9   10               Jimmy Butler   33  MIA      0        3
# 445          10   11               De'Aaron Fox   25  SAC      0        2
# 446          11  12T              Jalen Brunson   26  NYK      0        1
# 447          12  12T                  Ja Morant   23  MEM      0        1
# 448           0    1        Nikola JokiÃÂÃÂ   28  DEN     79      926
# 449           1    2    Shai Gilgeous-Alexander   25  OKC     15      640
# 450           2    3  Luka DonÃÂÃÂiÃÂÃÂ   24  DAL      4      566
# 451           3    4      Giannis Antetokounmpo   29  MIL      1      192
# 452           4    5              Jalen Brunson   27  NYK      0      142
# 453           5    6               Jayson Tatum   25  BOS      0       86
# 454           6    7            Anthony Edwards   22  MIN      0       18
# 455           7    8           Domantas Sabonis   27  SAC      0        3
# 456           8    9               Kevin Durant   35  PHO      0        1
#
#      Pts Max  Share   G  ...   TRB   AST  STL  BLK    FG%    3P%    FT%    WS  \
# 427     1000  0.146  65  ...   9.1   8.7  1.2  0.6  0.457  0.353  0.744   7.6
# 428     1000  0.043  76  ...   8.0   4.4  1.0  0.6  0.453  0.353  0.853   9.6
# 429     1000  0.010  57  ...   5.7   6.7  1.2  0.4  0.493  0.344  0.761   6.7
# 430     1000  0.004  64  ...   5.2   6.3  1.3  0.4  0.437  0.380  0.923   8.0
# 431     1000  0.002  65  ...   4.4  10.8  1.9  0.3  0.493  0.317  0.837   9.4
# 432     1000  0.001  76  ...   5.2   4.9  0.9  0.3  0.504  0.352  0.877   8.8
# 433     1000  0.001  55  ...   7.4   6.4  0.9  0.9  0.518  0.383  0.910   8.4
# 434     1000  0.001  56  ...   8.2   6.2  1.3  1.1  0.524  0.359  0.756   7.5
# 435     1000  0.915  66  ...  10.2   4.2  1.0  1.7  0.548  0.330  0.857  12.3
# 436     1000  0.674  69  ...  11.8   9.8  1.3  0.7  0.632  0.383  0.822  14.9
# 437     1000  0.606  63  ...  11.8   5.7  0.8  0.8  0.553  0.275  0.645   8.6
# 438     1000  0.280  74  ...   8.8   4.6  1.1  0.7  0.466  0.350  0.854  10.5
# 439     1000  0.046  68  ...   4.8   5.5  1.6  1.0  0.510  0.345  0.905  11.4
# 440     1000  0.030  68  ...   4.3   4.4  1.5  0.4  0.484  0.386  0.867   8.9
# 441     1000  0.027  79  ...  12.3   7.3  0.8  0.5  0.615  0.373  0.742  12.6
# 442     1000  0.010  66  ...   8.6   8.0  1.4  0.5  0.496  0.342  0.742  10.2
# 443     1000  0.005  56  ...   6.1   6.3  0.9  0.4  0.493  0.427  0.915   7.8
# 444     1000  0.003  64  ...   5.9   5.3  1.8  0.3  0.539  0.350  0.850  12.3
# 445     1000  0.002  73  ...   4.2   6.1  1.1  0.3  0.512  0.324  0.780   7.4
# 446     1000  0.001  68  ...   3.5   6.2  0.9  0.2  0.491  0.416  0.829   8.7
# 447     1000  0.001  61  ...   5.9   8.1  1.1  0.3  0.466  0.307  0.748   6.0
# 448      990  0.935  79  ...  12.4   9.0  1.4  0.9  0.583  0.359  0.817  17.0
# 449      990  0.646  75  ...   5.5   6.2  2.0  0.9  0.535  0.353  0.874  14.6
# 450      990  0.572  70  ...   9.2   9.8  1.4  0.5  0.487  0.382  0.786  12.0
# 451      990  0.194  73  ...  11.5   6.5  1.2  1.1  0.611  0.274  0.657  13.2
# 452      990  0.143  77  ...   3.6   6.7  0.9  0.2  0.479  0.401  0.847  11.2
# 453      990  0.087  74  ...   8.1   4.9  1.0  0.6  0.471  0.376  0.833  10.4
# 454      990  0.018  79  ...   5.4   5.1  1.3  0.5  0.461  0.357  0.836   7.5
# 455      990  0.003  82  ...  13.7   8.2  0.9  0.6  0.594  0.379  0.704  12.6
# 456      990  0.001  75  ...   6.6   5.0  0.9  1.2  0.523  0.413  0.856   8.3
#
#      WS/48  Year
# 427  0.159  2022
# 428  0.169  2022
# 429  0.171  2022
# 430  0.173  2022
# 431  0.210  2022
# 432  0.154  2022
# 433  0.198  2022
# 434  0.172  2022
# 435  0.259  2023
# 436  0.308  2023
# 437  0.204  2023
# 438  0.185  2023
# 439  0.226  2023
# 440  0.176  2023
# 441  0.221  2023
# 442  0.204  2023
# 443  0.192  2023
# 444  0.277  2023
# 445  0.146  2023
# 446  0.175  2023
# 447  0.148  2023
# 448  0.299  2024
# 449  0.275  2024
# 450  0.220  2024
# 451  0.246  2024
# 452  0.198  2024
# 453  0.189  2024
# 454  0.130  2024
# 455  0.206  2024
# 456  0.142  2024
#
# [30 rows x 22 columns]

# %%
mvps.replace({
    'ÃÂÃÂ' : 'a',
    'ÃÂÃÂiÃÂÃÂ' : 'c',
    'ÃÂ': 'č',  # You might need to add more mappings here
    'Ã': 'ć',
    'Ã': 'á',
    'Ã¡': 'á',
}, inplace=True)

# %%
mvps.tail(30)
# Out:
#      Unnamed: 0 Rank                     Player  Age   Tm  First  Pts Won  \
# 427           4    5  Luka DonÃÂÃÂiÃÂÃÂ   22  DAL      0      146
# 428           5    6               Jayson Tatum   23  BOS      0       43
# 429           6    7                  Ja Morant   22  MEM      0       10
# 430           7    8              Stephen Curry   33  GSW      0        4
# 431           8    9                 Chris Paul   36  PHO      0        2
# 432           9  10T              DeMar DeRozan   32  CHI      0        1
# 433          10  10T               Kevin Durant   33  BRK      0        1
# 434          11  10T               LeBron James   37  LAL      0        1
# 435           0    1                Joel Embiid   28  PHI     73      915
# 436           1    2        Nikola JokiÃÂÃÂ   27  DEN     15      674
# 437           2    3      Giannis Antetokounmpo   28  MIL     12      606
# 438           3    4               Jayson Tatum   24  BOS      0      280
# 439           4    5    Shai Gilgeous-Alexander   24  OKC      0       46
# 440           5    6           Donovan Mitchell   26  CLE      0       30
# 441           6    7           Domantas Sabonis   26  SAC      0       27
# 442           7    8  Luka DonÃÂÃÂiÃÂÃÂ   23  DAL      0       10
# 443           8    9              Stephen Curry   34  GSW      0        5
# 444           9   10               Jimmy Butler   33  MIA      0        3
# 445          10   11               De'Aaron Fox   25  SAC      0        2
# 446          11  12T              Jalen Brunson   26  NYK      0        1
# 447          12  12T                  Ja Morant   23  MEM      0        1
# 448           0    1        Nikola JokiÃÂÃÂ   28  DEN     79      926
# 449           1    2    Shai Gilgeous-Alexander   25  OKC     15      640
# 450           2    3  Luka DonÃÂÃÂiÃÂÃÂ   24  DAL      4      566
# 451           3    4      Giannis Antetokounmpo   29  MIL      1      192
# 452           4    5              Jalen Brunson   27  NYK      0      142
# 453           5    6               Jayson Tatum   25  BOS      0       86
# 454           6    7            Anthony Edwards   22  MIN      0       18
# 455           7    8           Domantas Sabonis   27  SAC      0        3
# 456           8    9               Kevin Durant   35  PHO      0        1
#
#      Pts Max  Share   G  ...   TRB   AST  STL  BLK    FG%    3P%    FT%    WS  \
# 427     1000  0.146  65  ...   9.1   8.7  1.2  0.6  0.457  0.353  0.744   7.6
# 428     1000  0.043  76  ...   8.0   4.4  1.0  0.6  0.453  0.353  0.853   9.6
# 429     1000  0.010  57  ...   5.7   6.7  1.2  0.4  0.493  0.344  0.761   6.7
# 430     1000  0.004  64  ...   5.2   6.3  1.3  0.4  0.437  0.380  0.923   8.0
# 431     1000  0.002  65  ...   4.4  10.8  1.9  0.3  0.493  0.317  0.837   9.4
# 432     1000  0.001  76  ...   5.2   4.9  0.9  0.3  0.504  0.352  0.877   8.8
# 433     1000  0.001  55  ...   7.4   6.4  0.9  0.9  0.518  0.383  0.910   8.4
# 434     1000  0.001  56  ...   8.2   6.2  1.3  1.1  0.524  0.359  0.756   7.5
# 435     1000  0.915  66  ...  10.2   4.2  1.0  1.7  0.548  0.330  0.857  12.3
# 436     1000  0.674  69  ...  11.8   9.8  1.3  0.7  0.632  0.383  0.822  14.9
# 437     1000  0.606  63  ...  11.8   5.7  0.8  0.8  0.553  0.275  0.645   8.6
# 438     1000  0.280  74  ...   8.8   4.6  1.1  0.7  0.466  0.350  0.854  10.5
# 439     1000  0.046  68  ...   4.8   5.5  1.6  1.0  0.510  0.345  0.905  11.4
# 440     1000  0.030  68  ...   4.3   4.4  1.5  0.4  0.484  0.386  0.867   8.9
# 441     1000  0.027  79  ...  12.3   7.3  0.8  0.5  0.615  0.373  0.742  12.6
# 442     1000  0.010  66  ...   8.6   8.0  1.4  0.5  0.496  0.342  0.742  10.2
# 443     1000  0.005  56  ...   6.1   6.3  0.9  0.4  0.493  0.427  0.915   7.8
# 444     1000  0.003  64  ...   5.9   5.3  1.8  0.3  0.539  0.350  0.850  12.3
# 445     1000  0.002  73  ...   4.2   6.1  1.1  0.3  0.512  0.324  0.780   7.4
# 446     1000  0.001  68  ...   3.5   6.2  0.9  0.2  0.491  0.416  0.829   8.7
# 447     1000  0.001  61  ...   5.9   8.1  1.1  0.3  0.466  0.307  0.748   6.0
# 448      990  0.935  79  ...  12.4   9.0  1.4  0.9  0.583  0.359  0.817  17.0
# 449      990  0.646  75  ...   5.5   6.2  2.0  0.9  0.535  0.353  0.874  14.6
# 450      990  0.572  70  ...   9.2   9.8  1.4  0.5  0.487  0.382  0.786  12.0
# 451      990  0.194  73  ...  11.5   6.5  1.2  1.1  0.611  0.274  0.657  13.2
# 452      990  0.143  77  ...   3.6   6.7  0.9  0.2  0.479  0.401  0.847  11.2
# 453      990  0.087  74  ...   8.1   4.9  1.0  0.6  0.471  0.376  0.833  10.4
# 454      990  0.018  79  ...   5.4   5.1  1.3  0.5  0.461  0.357  0.836   7.5
# 455      990  0.003  82  ...  13.7   8.2  0.9  0.6  0.594  0.379  0.704  12.6
# 456      990  0.001  75  ...   6.6   5.0  0.9  1.2  0.523  0.413  0.856   8.3
#
#      WS/48  Year
# 427  0.159  2022
# 428  0.169  2022
# 429  0.171  2022
# 430  0.173  2022
# 431  0.210  2022
# 432  0.154  2022
# 433  0.198  2022
# 434  0.172  2022
# 435  0.259  2023
# 436  0.308  2023
# 437  0.204  2023
# 438  0.185  2023
# 439  0.226  2023
# 440  0.176  2023
# 441  0.221  2023
# 442  0.204  2023
# 443  0.192  2023
# 444  0.277  2023
# 445  0.146  2023
# 446  0.175  2023
# 447  0.148  2023
# 448  0.299  2024
# 449  0.275  2024
# 450  0.220  2024
# 451  0.246  2024
# 452  0.198  2024
# 453  0.189  2024
# 454  0.130  2024
# 455  0.206  2024
# 456  0.142  2024
#
# [30 rows x 22 columns]

# %%
mvps = mvps[["Player", "Year", "Pts Won", "Pts Max", "Share"]]

# %%
mvps
# Out:
#                Player  Year  Pts Won  Pts Max  Share
# 0     Hakeem Olajuwon  1994      889     1010  0.880
# 1      David Robinson  1994      730     1010  0.723
# 2      Scottie Pippen  1994      390     1010  0.386
# 3    Shaquille O'Neal  1994      289     1010  0.286
# 4       Patrick Ewing  1994      255     1010  0.252
# ..                ...   ...      ...      ...    ...
# 452     Jalen Brunson  2024      142      990  0.143
# 453      Jayson Tatum  2024       86      990  0.087
# 454   Anthony Edwards  2024       18      990  0.018
# 455  Domantas Sabonis  2024        3      990  0.003
# 456      Kevin Durant  2024        1      990  0.001
#
# [457 rows x 5 columns]

# %%
players = pd.read_csv("csv/player_stats.csv")

# %%
players
# Out:
#        Unnamed: 0   Rk              Player Pos Age   Tm   G  GS    MP   FG  \
# 0               0    1      Alaa Abdelnaby  PF  25  BOS  13   0  12.2  1.8
# 1               1    2  Mahmoud Abdul-Rauf  PG  24  DEN  80  78  32.7  7.4
# 2               2    3       Michael Adams  PG  31  WSB  70  67  33.4  4.1
# 3               3    4        Mark Aguirre  SF  34  LAC  39   0  22.0  4.2
# 4               4    5         Danny Ainge  SG  34  PHO  68   1  22.9  3.3
# ...           ...  ...                 ...  ..  ..  ...  ..  ..   ...  ...
# 18944         757  568      Thaddeus Young  PF  35  PHO  10   0   8.9  1.1
# 18945         758  569          Trae Young  PG  25  ATL  54  54  36.0  8.0
# 18946         759  570      Omer Yurtseven   C  25  UTA  48  12  11.4  2.1
# 18947         760  571         Cody Zeller   C  31  NOP  43   0   7.4  0.6
# 18948         761  572         Ivica Zubac   C  26  LAC  68  68  26.4  5.0
#
#        ...  ORB  DRB  TRB   AST  STL  BLK  TOV   PF   PTS  Year
# 0      ...  0.9  2.6  3.5   0.2  0.2  0.2  1.3  1.5   4.9  1994
# 1      ...  0.3  1.8  2.1   4.5  1.0  0.1  1.9  1.9  18.0  1994
# 2      ...  0.5  2.1  2.6   6.9  1.4  0.1  2.4  2.0  12.1  1994
# 3      ...  0.7  2.3  3.0   2.7  0.5  0.2  1.8  2.5  10.6  1994
# 4      ...  0.4  1.5  1.9   2.6  0.8  0.1  1.2  2.1   8.9  1994
# ...    ...  ...  ...  ...   ...  ...  ...  ...  ...   ...   ...
# 18944  ...  1.7  1.1  2.8   0.7  0.5  0.2  0.4  1.1   2.3  2024
# 18945  ...  0.4  2.3  2.8  10.8  1.3  0.2  4.4  2.0  25.7  2024
# 18946  ...  1.5  2.8  4.3   0.6  0.2  0.4  0.8  1.1   4.6  2024
# 18947  ...  1.1  1.5  2.6   0.9  0.2  0.1  0.4  1.0   1.8  2024
# 18948  ...  2.9  6.3  9.2   1.4  0.3  1.2  1.2  2.6  11.7  2024
#
# [18949 rows x 32 columns]

# %%
del players["Unnamed: 0"]
del players["Rk"]

# %%
players.head()
# Out:
#                Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  ORB  \
# 0      Alaa Abdelnaby  PF  25  BOS  13   0  12.2  1.8   4.2  .436  ...  0.9
# 1  Mahmoud Abdul-Rauf  PG  24  DEN  80  78  32.7  7.4  16.0  .460  ...  0.3
# 2       Michael Adams  PG  31  WSB  70  67  33.4  4.1  10.0  .408  ...  0.5
# 3        Mark Aguirre  SF  34  LAC  39   0  22.0  4.2   8.9  .468  ...  0.7
# 4         Danny Ainge  SG  34  PHO  68   1  22.9  3.3   7.9  .417  ...  0.4
#
#    DRB  TRB  AST  STL  BLK  TOV   PF   PTS  Year
# 0  2.6  3.5  0.2  0.2  0.2  1.3  1.5   4.9  1994
# 1  1.8  2.1  4.5  1.0  0.1  1.9  1.9  18.0  1994
# 2  2.1  2.6  6.9  1.4  0.1  2.4  2.0  12.1  1994
# 3  2.3  3.0  2.7  0.5  0.2  1.8  2.5  10.6  1994
# 4  1.5  1.9  2.6  0.8  0.1  1.2  2.1   8.9  1994
#
# [5 rows x 30 columns]

# %%
players["Player"] = players["Player"].str.replace("*", "", regex=False) # Some players have a * at the end of their name

# %%
players.head(10)
# Out:
#                Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  ORB  \
# 0      Alaa Abdelnaby  PF  25  BOS  13   0  12.2  1.8   4.2  .436  ...  0.9
# 1  Mahmoud Abdul-Rauf  PG  24  DEN  80  78  32.7  7.4  16.0  .460  ...  0.3
# 2       Michael Adams  PG  31  WSB  70  67  33.4  4.1  10.0  .408  ...  0.5
# 3        Mark Aguirre  SF  34  LAC  39   0  22.0  4.2   8.9  .468  ...  0.7
# 4         Danny Ainge  SG  34  PHO  68   1  22.9  3.3   7.9  .417  ...  0.4
# 5      Gary Alexander  PF  24  TOT  11   0   5.0  0.7   1.3  .571  ...  0.6
# 6      Gary Alexander  PF  24  MIA   4   0   3.0  0.3   0.5  .500  ...  0.3
# 7      Gary Alexander  PF  24  CLE   7   0   6.1  1.0   1.7  .583  ...  0.9
# 8    Victor Alexander   C  24  GSW  69  39  19.1  3.9   7.3  .530  ...  1.7
# 9       Eric Anderson  PF  23  NYK  11   0   3.5  0.6   1.5  .412  ...  0.5
#
#    DRB  TRB  AST  STL  BLK  TOV   PF   PTS  Year
# 0  2.6  3.5  0.2  0.2  0.2  1.3  1.5   4.9  1994
# 1  1.8  2.1  4.5  1.0  0.1  1.9  1.9  18.0  1994
# 2  2.1  2.6  6.9  1.4  0.1  2.4  2.0  12.1  1994
# 3  2.3  3.0  2.7  0.5  0.2  1.8  2.5  10.6  1994
# 4  1.5  1.9  2.6  0.8  0.1  1.2  2.1   8.9  1994
# 5  0.7  1.4  0.2  0.3  0.0  0.7  0.9   1.7  1994
# 6  0.5  0.8  0.3  0.0  0.0  0.3  0.8   0.5  1994
# 7  0.9  1.7  0.1  0.4  0.0  1.0  1.0   2.4  1994
# 8  2.8  4.5  1.0  0.4  0.5  1.2  2.4   8.7  1994
# 9  1.0  1.5  0.2  0.0  0.1  0.2  0.8   1.9  1994
#
# [10 rows x 30 columns]

# %%
players.groupby(["Player", "Year"]).get_group(("Gary Alexander", 1994))
# Out:
#            Player Pos Age   Tm   G GS   MP   FG  FGA   FG%  ...  ORB  DRB  \
# 5  Gary Alexander  PF  24  TOT  11  0  5.0  0.7  1.3  .571  ...  0.6  0.7
# 6  Gary Alexander  PF  24  MIA   4  0  3.0  0.3  0.5  .500  ...  0.3  0.5
# 7  Gary Alexander  PF  24  CLE   7  0  6.1  1.0  1.7  .583  ...  0.9  0.9
#
#    TRB  AST  STL  BLK  TOV   PF  PTS  Year
# 5  1.4  0.2  0.3  0.0  0.7  0.9  1.7  1994
# 6  0.8  0.3  0.0  0.0  0.3  0.8  0.5  1994
# 7  1.7  0.1  0.4  0.0  1.0  1.0  2.4  1994
#
# [3 rows x 30 columns]

# %%
def single_row(df):
    if df.shape[0] == 1:
        return df
    else:
        row = df[df["Tm"] == "TOT"]
        row["Tm"] = df.iloc[-1,:]["Tm"]
        return row

players = players.groupby(["Player", "Year"]).apply(single_row)
# Out:
# /var/folders/0p/_6483prs69vgz_scs5wdyb940000gn/T/ipykernel_1603/3467767470.py:9: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   players = players.groupby(["Player", "Year"]).apply(single_row)

# %%
players.head(20)
# Out:
#                                  Player Pos Age   Tm   G  GS    MP   FG   FGA  \
# Player        Year
# A.C. Green    1994 177       A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3
#               1995 665       A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5
#               1996 1161      A.C. Green  SF  32  PHO  82  36  25.8  2.6   5.4
#               1997 1736      A.C. Green  PF  33  DAL  83  73  30.0  2.8   5.8
#               1998 2323      A.C. Green  PF  34  DAL  82  68  32.3  3.0   6.5
#               1999 2881      A.C. Green  PF  35  DAL  50  35  18.5  2.2   5.1
#               2000 3409      A.C. Green  PF  36  LAL  82  82  23.5  2.1   4.7
#               2001 3928      A.C. Green  PF  37  MIA  82   1  17.2  1.8   4.0
# A.J. Bramlett 2000 3282   A.J. Bramlett   C  23  CLE   8   0   7.6  0.5   2.6
# A.J. Green    2023 17713     A.J. Green  SG  23  MIL  35   1   9.9  1.5   3.6
#               2024 18445     A.J. Green  SG  24  MIL  56   0  11.0  1.5   3.5
# A.J. Guyton   2001 3931     A.J. Guyton  PG  22  CHI  33   8  19.1  2.4   5.8
#               2002 4484     A.J. Guyton  PG  23  CHI  45   6  13.5  2.0   5.4
#               2003 4991     A.J. Guyton  PG  24  GSW   2   0   4.5  0.0   2.0
# A.J. Hammons  2017 13412   A.J. Hammons   C  24  DAL  22   0   7.4  0.8   1.9
# A.J. Lawson   2023 17857    A.J. Lawson  SG  22  DAL  15   0   7.2  1.5   2.9
#               2024 18567    A.J. Lawson  SG  23  DAL  42   0   7.4  1.3   2.9
# A.J. Price    2010 9325      A.J. Price  PG  23  IND  56   2  15.4  2.6   6.3
#               2011 9954      A.J. Price  PG  24  IND  50   0  15.9  2.3   6.4
#               2012 10538     A.J. Price  PG  25  IND  44   1  12.9  1.3   4.0
#
#                            FG%  ...  ORB  DRB  TRB  AST  STL  BLK  TOV   PF  \
# Player        Year              ...
# A.C. Green    1994 177    .502  ...  3.4  5.8  9.2  1.7  0.9  0.5  1.2  1.7
#               1995 665    .504  ...  2.4  5.8  8.2  1.5  0.7  0.4  1.4  1.8
#               1996 1161   .484  ...  2.0  4.7  6.8  0.9  0.5  0.3  1.0  1.7
#               1997 1736   .483  ...  2.7  5.2  7.9  0.8  0.8  0.2  0.9  1.7
#               1998 2323   .453  ...  2.7  5.5  8.1  1.5  1.0  0.3  0.8  1.9
#               1999 2881   .422  ...  1.6  2.9  4.6  0.5  0.6  0.2  0.4  1.4
#               2000 3409   .447  ...  2.0  4.0  5.9  1.0  0.6  0.2  0.6  1.5
#               2001 3928   .444  ...  1.3  2.5  3.8  0.5  0.4  0.1  0.5  1.5
# A.J. Bramlett 2000 3282   .190  ...  1.5  1.3  2.8  0.0  0.1  0.0  0.4  1.6
# A.J. Green    2023 17713  .424  ...  0.2  1.1  1.3  0.6  0.2  0.0  0.3  0.9
#               2024 18445  .423  ...  0.2  1.0  1.1  0.5  0.2  0.1  0.2  0.9
# A.J. Guyton   2001 3931   .406  ...  0.3  0.8  1.1  1.9  0.3  0.2  0.7  1.1
#               2002 4484   .361  ...  0.3  0.7  1.0  1.8  0.2  0.2  0.8  0.5
#               2003 4991   .000  ...  0.0  0.0  0.0  1.0  0.5  0.0  0.5  0.0
# A.J. Hammons  2017 13412  .405  ...  0.4  1.3  1.6  0.2  0.0  0.6  0.5  1.0
# A.J. Lawson   2023 17857  .500  ...  0.4  1.0  1.4  0.1  0.1  0.0  0.2  0.7
#               2024 18567  .446  ...  0.3  0.9  1.2  0.5  0.2  0.1  0.3  0.5
# A.J. Price    2010 9325   .410  ...  0.2  1.4  1.6  1.9  0.6  0.1  1.1  0.9
#               2011 9954   .356  ...  0.3  1.1  1.4  2.2  0.6  0.0  1.1  1.2
#               2012 10538  .339  ...  0.3  1.1  1.4  2.0  0.5  0.0  0.7  0.7
#
#                            PTS  Year
# Player        Year
# A.C. Green    1994 177    14.7  1994
#               1995 665    11.2  1995
#               1996 1161    7.5  1996
#               1997 1736    7.2  1997
#               1998 2323    7.3  1998
#               1999 2881    4.9  1999
#               2000 3409    5.0  2000
#               2001 3928    4.5  2001
# A.J. Bramlett 2000 3282    1.0  2000
# A.J. Green    2023 17713   4.4  2023
#               2024 18445   4.5  2024
# A.J. Guyton   2001 3931    6.0  2001
#               2002 4484    5.4  2002
#               2003 4991    0.0  2003
# A.J. Hammons  2017 13412   2.2  2017
# A.J. Lawson   2023 17857   3.7  2023
#               2024 18567   3.2  2024
# A.J. Price    2010 9325    7.3  2010
#               2011 9954    6.5  2011
#               2012 10538   3.9  2012
#
# [20 rows x 30 columns]

# %%
players.index = players.index.droplevel()

# %%
players.index = players.index.droplevel()

# %%
players.tail(100)
# Out:
#                Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  ORB  \
# 9338    Zach Randolph  PF  28  MEM  81  81  37.7  8.0  16.5  .488  ...  4.1
# 9966    Zach Randolph  PF  29  MEM  75  74  36.3  8.0  15.8  .503  ...  4.3
# 10545   Zach Randolph  PF  30  MEM  28   8  26.3  4.7  10.2  .463  ...  2.8
# 11141   Zach Randolph  PF  31  MEM  76  75  34.3  6.2  13.5  .460  ...  4.1
# 11768   Zach Randolph  PF  32  MEM  79  79  34.2  7.1  15.2  .467  ...  3.4
# ...               ...  ..  ..  ...  ..  ..   ...  ...   ...   ...  ...  ...
# 4693   Željko Rebrača   C  29  DET  74   4  15.9  2.6   5.1  .505  ...  1.1
# 5193   Željko Rebrača   C  30  DET  30  12  16.3  2.7   4.8  .552  ...  0.9
# 5774   Željko Rebrača   C  31  ATL  24   2  11.4  1.4   3.2  .442  ...  1.0
# 6374   Željko Rebrača   C  32  LAC  58   2  16.0  2.3   4.0  .568  ...  0.8
# 6968   Željko Rebrača   C  33  LAC  29   2  14.2  1.8   3.3  .542  ...  0.4
#
#        DRB   TRB  AST  STL  BLK  TOV   PF   PTS  Year
# 9338   7.7  11.7  1.8  1.0  0.4  2.1  2.8  20.8  2010
# 9966   7.8  12.2  2.2  0.8  0.3  2.0  2.3  20.1  2011
# 10545  5.3   8.0  1.7  0.8  0.1  1.4  2.0  11.6  2012
# 11141  7.2  11.2  1.4  0.8  0.4  2.0  2.4  15.4  2013
# 11768  6.7  10.1  2.5  0.7  0.3  2.3  2.7  17.4  2014
# ...    ...   ...  ...  ...  ...  ...  ...   ...   ...
# 4693   2.8   3.9  0.5  0.4  1.0  1.1  2.6   6.9  2002
# 5193   2.2   3.1  0.3  0.2  0.6  1.0  2.6   6.6  2003
# 5774   1.5   2.4  0.3  0.2  0.5  0.7  2.2   3.8  2004
# 6374   2.3   3.2  0.4  0.2  0.7  0.8  2.2   5.8  2005
# 6968   1.8   2.2  0.3  0.2  0.7  0.8  2.0   4.7  2006
#
# [100 rows x 30 columns]

# %%
combined = players.merge(mvps, how="outer", on=["Player", "Year"])

# %%
combined.tail(5)
# Out:
#                Player Pos Age   Tm   G  GS    MP   FG  FGA   FG%  ...  STL  \
# 14659  Željko Rebrača   C  29  DET  74   4  15.9  2.6  5.1  .505  ...  0.4
# 14660  Željko Rebrača   C  30  DET  30  12  16.3  2.7  4.8  .552  ...  0.2
# 14661  Željko Rebrača   C  31  ATL  24   2  11.4  1.4  3.2  .442  ...  0.2
# 14662  Željko Rebrača   C  32  LAC  58   2  16.0  2.3  4.0  .568  ...  0.2
# 14663  Željko Rebrača   C  33  LAC  29   2  14.2  1.8  3.3  .542  ...  0.2
#
#        BLK  TOV   PF  PTS  Year Pts Won Pts Max Share                  Team
# 14659  1.0  1.1  2.6  6.9  2002     0.0     0.0   0.0       Detroit Pistons
# 14660  0.6  1.0  2.6  6.6  2003     0.0     0.0   0.0       Detroit Pistons
# 14661  0.5  0.7  2.2  3.8  2004     0.0     0.0   0.0         Atlanta Hawks
# 14662  0.7  0.8  2.2  5.8  2005     0.0     0.0   0.0  Los Angeles Clippers
# 14663  0.7  0.8  2.0  4.7  2006     0.0     0.0   0.0  Los Angeles Clippers
#
# [5 rows x 34 columns]

# %%
combined[["Pts Won", "Pts Max", "Share"]] = combined[["Pts Won", "Pts Max", "Share"]].fillna(0)

# %%
combined.head(5)
# Out:
#        Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  AST  STL  BLK  \
# 0  A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3  .502  ...  1.7  0.9  0.5
# 1  A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5  .504  ...  1.5  0.7  0.4
# 2  A.C. Green  SF  32  PHO  82  36  25.8  2.6   5.4  .484  ...  0.9  0.5  0.3
# 3  A.C. Green  PF  33  DAL  83  73  30.0  2.8   5.8  .483  ...  0.8  0.8  0.2
# 4  A.C. Green  PF  34  DAL  82  68  32.3  3.0   6.5  .453  ...  1.5  1.0  0.3
#
#    TOV   PF   PTS  Year Pts Won Pts Max Share
# 0  1.2  1.7  14.7  1994     0.0     0.0   0.0
# 1  1.4  1.8  11.2  1995     0.0     0.0   0.0
# 2  1.0  1.7   7.5  1996     0.0     0.0   0.0
# 3  0.9  1.7   7.2  1997     0.0     0.0   0.0
# 4  0.8  1.9   7.3  1998     0.0     0.0   0.0
#
# [5 rows x 33 columns]

# %%
teams = pd.read_csv("csv/teams.csv")

# %%
teams.head(10)
# Out:
#    Unnamed: 0                 W                 L              W/L%  \
# 0           0                57                25              .695
# 1           1                50                32              .610
# 2           2                45                37              .549
# 3           3                42                40              .512
# 4           4                32                50              .390
# 5           5                25                57              .305
# 6           6                24                58              .293
# 7           7  Central Division  Central Division  Central Division
# 8           8                57                25              .695
# 9           9                55                27              .671
#
#                  GB              PS/G              PA/G               SRS  \
# 0                 —              98.5              91.5              6.48
# 1               7.0             105.7             101.8              3.68
# 2              12.0             103.2             101.0              2.11
# 3              15.0             103.4             100.7              2.40
# 4              25.0             100.8             105.1             -4.28
# 5              32.0              98.0             105.6             -7.37
# 6              33.0             100.4             107.7             -7.13
# 7  Central Division  Central Division  Central Division  Central Division
# 8                 —             101.4              96.2              4.94
# 9               2.0              98.0              94.9              2.87
#
#    Year                Team
# 0  1994    New York Knicks*
# 1  1994      Orlando Magic*
# 2  1994    New Jersey Nets*
# 3  1994         Miami Heat*
# 4  1994      Boston Celtics
# 5  1994  Philadelphia 76ers
# 6  1994  Washington Bullets
# 7  1994    Central Division
# 8  1994      Atlanta Hawks*
# 9  1994      Chicago Bulls*

# %%
teams = teams[~teams["W"].str.contains("Division")]

# %%
teams.head(10)
# Out:
#     Unnamed: 0   W   L  W/L%    GB   PS/G   PA/G    SRS  Year  \
# 0            0  57  25  .695     —   98.5   91.5   6.48  1994
# 1            1  50  32  .610   7.0  105.7  101.8   3.68  1994
# 2            2  45  37  .549  12.0  103.2  101.0   2.11  1994
# 3            3  42  40  .512  15.0  103.4  100.7   2.40  1994
# 4            4  32  50  .390  25.0  100.8  105.1  -4.28  1994
# 5            5  25  57  .305  32.0   98.0  105.6  -7.37  1994
# 6            6  24  58  .293  33.0  100.4  107.7  -7.13  1994
# 8            8  57  25  .695     —  101.4   96.2   4.94  1994
# 9            9  55  27  .671   2.0   98.0   94.9   2.87  1994
# 10          10  47  35  .573  10.0  101.0   97.5   3.26  1994
#
#                   Team
# 0     New York Knicks*
# 1       Orlando Magic*
# 2     New Jersey Nets*
# 3          Miami Heat*
# 4       Boston Celtics
# 5   Philadelphia 76ers
# 6   Washington Bullets
# 8       Atlanta Hawks*
# 9       Chicago Bulls*
# 10     Indiana Pacers*

# %%
teams["Team"] = teams["Team"].str.replace("*", "", regex=False)

# %%
del teams["Unnamed: 0"]

# %%
teams.head(5)
# Out:
#     W   L  W/L%    GB   PS/G   PA/G    SRS  Year             Team
# 0  57  25  .695     —   98.5   91.5   6.48  1994  New York Knicks
# 1  50  32  .610   7.0  105.7  101.8   3.68  1994    Orlando Magic
# 2  45  37  .549  12.0  103.2  101.0   2.11  1994  New Jersey Nets
# 3  42  40  .512  15.0  103.4  100.7   2.40  1994       Miami Heat
# 4  32  50  .390  25.0  100.8  105.1  -4.28  1994   Boston Celtics

# %%
teams["Team"].unique()
# Out:
# array(['New York Knicks', 'Orlando Magic', 'New Jersey Nets',
#        'Miami Heat', 'Boston Celtics', 'Philadelphia 76ers',
#        'Washington Bullets', 'Atlanta Hawks', 'Chicago Bulls',
#        'Indiana Pacers', 'Cleveland Cavaliers', 'Charlotte Hornets',
#        'Milwaukee Bucks', 'Detroit Pistons', 'Houston Rockets',
#        'San Antonio Spurs', 'Utah Jazz', 'Denver Nuggets',
#        'Minnesota Timberwolves', 'Dallas Mavericks',
#        'Seattle SuperSonics', 'Phoenix Suns', 'Golden State Warriors',
#        'Portland Trail Blazers', 'Los Angeles Lakers', 'Sacramento Kings',
#        'Los Angeles Clippers', 'Toronto Raptors', 'Vancouver Grizzlies',
#        'Washington Wizards', 'Memphis Grizzlies', 'New Orleans Hornets',
#        'Charlotte Bobcats', 'New Orleans/Oklahoma City Hornets',
#        'Oklahoma City Thunder', 'Brooklyn Nets', 'New Orleans Pelicans'],
#       dtype=object)

# %%
combined["Tm"].unique()
# Out:
# array(['PHO', 'DAL', 'LAL', 'MIA', 'CLE', 'MIL', 'CHI', 'GSW', 'IND',
#        'WAS', 'MIN', 'ATL', 'HOU', 'DEN', 'ORL', 'NOH', 'TOR', 'SAC',
#        'CHO', 'PHI', 'POR', 'DET', 'BOS', 'OKC', 'UTA', 'VAN', 'SEA',
#        'NJN', 'NOK', 'LAC', 'CHA', 'MEM', 'NYK', 'NOP', 'BRK', 'SAS',
#        'CHH', 'WSB', nan], dtype=object)

# %%
data = {
    "Abbreviation": ["ATL", "BRK", "BKN", "BOS", "CHA", "CHH", "CHO", "CHI", "CLE", "DAL",
                     "DEN", "DET", "GSW", "HOU", "IND", "LAC", "LAL", "MEM", "MIA", "MIL",
                     "MIN", "NJN", "NOH", "NOP", "NOK", "NYK", "OKC", "ORL", "PHI", "PHX",
                     "PHO", "POR", "SEA", "SAC", "SAS", "TOR", "UTA", "VAN", "WAS", "WSB"],
    "Name": ["Atlanta Hawks", "Brooklyn Nets", "Brooklyn Nets", "Boston Celtics", "Charlotte Bobcats",
             "Charlotte Hornets", "Charlotte Hornets", "Chicago Bulls", "Cleveland Cavaliers",
             "Dallas Mavericks", "Denver Nuggets", "Detroit Pistons", "Golden State Warriors",
             "Houston Rockets", "Indiana Pacers", "Los Angeles Clippers", "Los Angeles Lakers",
             "Memphis Grizzlies", "Miami Heat", "Milwaukee Bucks", "Minnesota Timberwolves",
             "New Jersey Nets", "New Orleans Hornets", "New Orleans Pelicans",
             "New Orleans/Oklahoma City Hornets", "New York Knicks", "Oklahoma City Thunder",
             "Orlando Magic", "Philadelphia 76ers", "Phoenix Suns", "Phoenix Suns",
             "Portland Trail Blazers", "Seattle SuperSonics", "Sacramento Kings",
             "San Antonio Spurs", "Toronto Raptors", "Utah Jazz", "Vancouver Grizzlies",
             "Washington Wizards", "Washington Bullets"]
}

team_names = pd.DataFrame(data)
team_names.to_csv("csv/teamNames.csv", index=False)

# %%
nicknames = {}

with open("csv/teamNames.csv") as f:
    lines = f.readlines()
    for line in lines[1:]:
        abb, name = line.replace("\n", "").split(",")
        nicknames[abb] = name

# %%
combined["Tm"]
# Out:
# 0        PHO
# 1        PHO
# 2        PHO
# 3        DAL
# 4        DAL
#         ...
# 14659    DET
# 14660    DET
# 14661    ATL
# 14662    LAC
# 14663    LAC
# Name: Tm, Length: 14664, dtype: object

# %%
combined["Team"] = combined["Tm"].map(nicknames)

# %%
combined[combined["Player"] == "Nikola Jokić"]
# Out:
#              Player Pos Age   Tm   G  GS    MP    FG   FGA   FG%  ...  STL  \
# 10679  Nikola Jokić   C  20  DEN  80  55  21.7   3.8   7.5  .512  ...  1.0
# 10680  Nikola Jokić   C  21  DEN  73  59  27.9   6.8  11.7  .578  ...  0.8
# 10681  Nikola Jokić   C  22  DEN  75  73  32.6   6.7  13.5  .499  ...  1.2
# 10682  Nikola Jokić   C  23  DEN  80  80  31.3   7.7  15.1  .511  ...  1.4
# 10683  Nikola Jokić   C  24  DEN  73  73  32.0   7.7  14.7  .528  ...  1.2
# 10684  Nikola Jokić   C  25  DEN  72  72  34.6  10.2  18.0  .566  ...  1.3
# 10685  Nikola Jokić   C  26  DEN  74  74  33.5  10.3  17.7  .583  ...  1.5
# 10686  Nikola Jokić   C  27  DEN  69  69  33.7   9.4  14.8  .632  ...  1.3
# 10687  Nikola Jokić   C  28  DEN  79  79  34.6  10.4  17.9  .583  ...  1.4
#
#        BLK  TOV   PF   PTS  Year Pts Won Pts Max Share            Team
# 10679  0.6  1.3  2.6  10.0  2016     0.0     0.0   0.0  Denver Nuggets
# 10680  0.8  2.3  2.9  16.7  2017     0.0     0.0   0.0  Denver Nuggets
# 10681  0.8  2.8  2.8  18.5  2018     0.0     0.0   0.0  Denver Nuggets
# 10682  0.7  3.1  2.9  20.1  2019     0.0     0.0   0.0  Denver Nuggets
# 10683  0.6  3.1  3.0  19.9  2020     0.0     0.0   0.0  Denver Nuggets
# 10684  0.7  3.1  2.7  26.4  2021     0.0     0.0   0.0  Denver Nuggets
# 10685  0.9  3.8  2.6  27.1  2022     0.0     0.0   0.0  Denver Nuggets
# 10686  0.7  3.6  2.5  24.5  2023     0.0     0.0   0.0  Denver Nuggets
# 10687  0.9  3.0  2.5  26.4  2024     0.0     0.0   0.0  Denver Nuggets
#
# [9 rows x 34 columns]

# %%
stats = combined.merge(teams, how="outer", on=["Team", "Year"])

# %%
stats.tail(30)
# Out:
#                     Player   Pos  Age   Tm    G   GS    MP   FG   FGA   FG%  \
# 14634       Hamidou Diallo    SG   25  WAS    2    0   2.5  0.5   1.0  .500
# 14635         Jared Butler    SG   23  WAS   40    0  14.2  2.5   5.0  .488
# 14636         Johnny Davis    SG   21  WAS   50    6  12.3  1.2   3.1  .403
# 14637         Jordan Poole    SG   24  WAS   78   66  30.1  6.3  15.2  .413
# 14638        Jules Bernard    SG   24  WAS   19    0   7.8  1.5   3.4  .453
# 14639    Justin Champagnie    SF   22  WAS   15    1  15.7  2.1   5.2  .410
# 14640           Kyle Kuzma    PF   28  WAS   70   70  32.6  8.7  18.8  .463
# 14641        Landry Shamet    SG   26  WAS   46    5  15.8  2.6   6.0  .431
# 14642    Marvin Bagley III     C   24  WAS   50   25  21.1  4.8   8.2  .586
# 14643  Patrick Baldwin Jr.    SF   21  WAS   38    7  13.0  1.6   4.1  .381
# 14644       Richaun Holmes  C-PF   30  WAS   40   10  13.9  2.1   3.7  .558
# 14645     Tristan Vukcevic     C   20  WAS   10    4  15.3  2.9   6.7  .433
# 14646           Tyus Jones    PG   27  WAS   66   66  29.3  4.9  10.1  .489
# 14647     Peja StojakoviÄ   NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN   NaN
# 14648     Peja StojakoviÄ   NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN   NaN
# 14649       Manu GinÃ³bili   NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN   NaN
# 14650       Manu GinÃ³bili   NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN   NaN
# 14651       Manu GinÃ³bili   NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN   NaN
# 14652        Goran DragiÄ   NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN   NaN
# 14653        Nikola JokiÄ   NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN   NaN
# 14654        Luka DonÄiÄ   NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN   NaN
# 14655        Nikola JokiÄ   NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN   NaN
# 14656        Luka DonÄiÄ   NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN   NaN
# 14657        Nikola JokiÄ   NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN   NaN
# 14658        Luka DonÄiÄ   NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN   NaN
# 14659        Nikola JokiÄ   NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN   NaN
# 14660        Luka DonÄiÄ   NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN   NaN
# 14661        Nikola JokiÄ   NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN   NaN
# 14662        Luka DonÄiÄ   NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN   NaN
# 14663        Nikola JokiÄ   NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN   NaN
#
#        ... Pts Max  Share                Team    W    L  W/L%    GB   PS/G  \
# 14634  ...     0.0  0.000  Washington Wizards   15   67  .183  32.0  113.7
# 14635  ...     0.0  0.000  Washington Wizards   15   67  .183  32.0  113.7
# 14636  ...     0.0  0.000  Washington Wizards   15   67  .183  32.0  113.7
# 14637  ...     0.0  0.000  Washington Wizards   15   67  .183  32.0  113.7
# 14638  ...     0.0  0.000  Washington Wizards   15   67  .183  32.0  113.7
# 14639  ...     0.0  0.000  Washington Wizards   15   67  .183  32.0  113.7
# 14640  ...     0.0  0.000  Washington Wizards   15   67  .183  32.0  113.7
# 14641  ...     0.0  0.000  Washington Wizards   15   67  .183  32.0  113.7
# 14642  ...     0.0  0.000  Washington Wizards   15   67  .183  32.0  113.7
# 14643  ...     0.0  0.000  Washington Wizards   15   67  .183  32.0  113.7
# 14644  ...     0.0  0.000  Washington Wizards   15   67  .183  32.0  113.7
# 14645  ...     0.0  0.000  Washington Wizards   15   67  .183  32.0  113.7
# 14646  ...     0.0  0.000  Washington Wizards   15   67  .183  32.0  113.7
# 14647  ...  1260.0  0.001                 NaN  NaN  NaN   NaN   NaN    NaN
# 14648  ...  1230.0  0.228                 NaN  NaN  NaN   NaN   NaN    NaN
# 14649  ...  1260.0  0.007                 NaN  NaN  NaN   NaN   NaN    NaN
# 14650  ...  1230.0  0.002                 NaN  NaN  NaN   NaN   NaN    NaN
# 14651  ...  1210.0  0.017                 NaN  NaN  NaN   NaN   NaN    NaN
# 14652  ...  1250.0  0.002                 NaN  NaN  NaN   NaN   NaN    NaN
# 14653  ...  1010.0  0.210                 NaN  NaN  NaN   NaN   NaN    NaN
# 14654  ...  1010.0  0.198                 NaN  NaN  NaN   NaN   NaN    NaN
# 14655  ...  1010.0  0.018                 NaN  NaN  NaN   NaN   NaN    NaN
# 14656  ...  1010.0  0.042                 NaN  NaN  NaN   NaN   NaN    NaN
# 14657  ...  1010.0  0.961                 NaN  NaN  NaN   NaN   NaN    NaN
# 14658  ...  1000.0  0.146                 NaN  NaN  NaN   NaN   NaN    NaN
# 14659  ...  1000.0  0.875                 NaN  NaN  NaN   NaN   NaN    NaN
# 14660  ...  1000.0  0.010                 NaN  NaN  NaN   NaN   NaN    NaN
# 14661  ...  1000.0  0.674                 NaN  NaN  NaN   NaN   NaN    NaN
# 14662  ...   990.0  0.572                 NaN  NaN  NaN   NaN   NaN    NaN
# 14663  ...   990.0  0.935                 NaN  NaN  NaN   NaN   NaN    NaN
#
#         PA/G    SRS
# 14634  123.0  -9.29
# 14635  123.0  -9.29
# 14636  123.0  -9.29
# 14637  123.0  -9.29
# 14638  123.0  -9.29
# 14639  123.0  -9.29
# 14640  123.0  -9.29
# 14641  123.0  -9.29
# 14642  123.0  -9.29
# 14643  123.0  -9.29
# 14644  123.0  -9.29
# 14645  123.0  -9.29
# 14646  123.0  -9.29
# 14647    NaN    NaN
# 14648    NaN    NaN
# 14649    NaN    NaN
# 14650    NaN    NaN
# 14651    NaN    NaN
# 14652    NaN    NaN
# 14653    NaN    NaN
# 14654    NaN    NaN
# 14655    NaN    NaN
# 14656    NaN    NaN
# 14657    NaN    NaN
# 14658    NaN    NaN
# 14659    NaN    NaN
# 14660    NaN    NaN
# 14661    NaN    NaN
# 14662    NaN    NaN
# 14663    NaN    NaN
#
# [30 rows x 41 columns]
